# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd

factories = pd.read_csv("tbl_factory.csv",index_col = 0)
factories
# Out:
#         FCName  FCDemand FCRegion
# FCID
# FC00001   서울공장        28       북부
# FC00002   수원공장        29       북부
# FC00003   인천공장        31       북부
# FC00004   대전공장        25       북부
# FC00005   대구공장        21       남부
# FC00006   광주공장        30       남부
# FC00007   부산공장        25       남부
# FC00008   울산공장        16       남부

# %%
warehouses = pd.read_csv("tbl_warehouse.csv", index_col = 0)
warehouses
# Out:
#         WHName  WHSupply WHRegion
# WHID
# WH00001   판교창고        35       북부
# WH00002   용인창고        41       북부
# WH00003   수원창고        42       북부
# WH00004   대전창고        60       남부
# WH00005   대구창고        72       남부
# WH00006   광주창고        65       남부

# %%
cost = pd.read_csv('rel_cost.csv', index_col = 0)
cost.head()
# Out:
#             FCID     WHID  Cost
# RCostID
# 1        FC00001  WH00001   0.4
# 2        FC00001  WH00002   0.8
# 3        FC00001  WH00003   1.5
# 4        FC00002  WH00001   0.9
# 5        FC00002  WH00002   0.8

# %%
trans = pd.read_csv('tbl_transaction.csv', index_col = 0)
trans.head()
# Out:
#           TransactionDate     ToFC   FromWH  Quantity
# TRID
# 0     2019-01-01 02:11:10  FC00004  WH00003        33
# 1     2019-01-01 06:12:42  FC00007  WH00006        19
# 2     2019-01-01 06:32:32  FC00006  WH00004        31
# 3     2019-01-01 07:17:06  FC00002  WH00003        18
# 4     2019-01-01 07:52:18  FC00001  WH00002        30

# %%
join_data = pd.merge(trans,cost, left_on = ["ToFC","FromWH"], right_on = ["FCID","WHID"], how = "left")
join_data.head()
# Out:
#        TransactionDate     ToFC   FromWH  Quantity     FCID     WHID  Cost
# 0  2019-01-01 02:11:10  FC00004  WH00003        33  FC00004  WH00003   1.1
# 1  2019-01-01 06:12:42  FC00007  WH00006        19  FC00007  WH00006   1.3
# 2  2019-01-01 06:32:32  FC00006  WH00004        31  FC00006  WH00004   0.9
# 3  2019-01-01 07:17:06  FC00002  WH00003        18  FC00002  WH00003   1.6
# 4  2019-01-01 07:52:18  FC00001  WH00002        30  FC00001  WH00002   0.8

# %%
join_data = pd.merge(join_data, factories, left_on = "ToFC", right_on = "FCID", how = "left")
join_data.head()
# Out:
#        TransactionDate     ToFC   FromWH  Quantity     FCID     WHID  Cost  \
# 0  2019-01-01 02:11:10  FC00004  WH00003        33  FC00004  WH00003   1.1
# 1  2019-01-01 06:12:42  FC00007  WH00006        19  FC00007  WH00006   1.3
# 2  2019-01-01 06:32:32  FC00006  WH00004        31  FC00006  WH00004   0.9
# 3  2019-01-01 07:17:06  FC00002  WH00003        18  FC00002  WH00003   1.6
# 4  2019-01-01 07:52:18  FC00001  WH00002        30  FC00001  WH00002   0.8
#
#   FCName  FCDemand FCRegion
# 0   대전공장        25       북부
# 1   부산공장        25       남부
# 2   광주공장        30       남부
# 3   수원공장        29       북부
# 4   서울공장        28       북부

# %%
join_data = pd.merge(join_data, warehouses, left_on = "FromWH", right_on = "WHID", how = "left")

join_data = join_data[["TransactionDate","Quantity","Cost","ToFC","FCName","FCDemand","FromWH","WHName","WHSupply","WHRegion"]]
join_data.head()
# Out:
#        TransactionDate  Quantity  Cost     ToFC FCName  FCDemand   FromWH  \
# 0  2019-01-01 02:11:10        33   1.1  FC00004   대전공장        25  WH00003
# 1  2019-01-01 06:12:42        19   1.3  FC00007   부산공장        25  WH00006
# 2  2019-01-01 06:32:32        31   0.9  FC00006   광주공장        30  WH00004
# 3  2019-01-01 07:17:06        18   1.6  FC00002   수원공장        29  WH00003
# 4  2019-01-01 07:52:18        30   0.8  FC00001   서울공장        28  WH00002
#
#   WHName  WHSupply WHRegion
# 0   수원창고        42       북부
# 1   광주창고        65       남부
# 2   대전창고        60       남부
# 3   수원창고        42       북부
# 4   용인창고        41       북부

# %%
south = join_data.loc[join_data["WHRegion"] == "남부"]
south.head()
# Out:
#        TransactionDate  Quantity  Cost     ToFC FCName  FCDemand   FromWH  \
# 1  2019-01-01 06:12:42        19   1.3  FC00007   부산공장        25  WH00006
# 2  2019-01-01 06:32:32        31   0.9  FC00006   광주공장        30  WH00004
# 5  2019-01-01 08:56:09        31   0.3  FC00005   대구공장        21  WH00005
# 6  2019-01-01 09:00:15        33   0.7  FC00006   광주공장        30  WH00006
# 9  2019-01-01 14:12:51        21   0.7  FC00006   광주공장        30  WH00006
#
#   WHName  WHSupply WHRegion
# 1   광주창고        65       남부
# 2   대전창고        60       남부
# 5   대구창고        72       남부
# 6   광주창고        65       남부
# 9   광주창고        65       남부

# %%
join_data = pd.merge(join_data, factories, left_on = "ToFC", right_on = "FCID", how = "left")
join_data.head()
# Out:
#        TransactionDate  Quantity  Cost     ToFC FCName_x  FCDemand_x   FromWH  \
# 0  2019-01-01 02:11:10        33   1.1  FC00004     대전공장          25  WH00003
# 1  2019-01-01 06:12:42        19   1.3  FC00007     부산공장          25  WH00006
# 2  2019-01-01 06:32:32        31   0.9  FC00006     광주공장          30  WH00004
# 3  2019-01-01 07:17:06        18   1.6  FC00002     수원공장          29  WH00003
# 4  2019-01-01 07:52:18        30   0.8  FC00001     서울공장          28  WH00002
#
#   WHName  WHSupply WHRegion FCName_y  FCDemand_y FCRegion
# 0   수원창고        42       북부     대전공장          25       북부
# 1   광주창고        65       남부     부산공장          25       남부
# 2   대전창고        60       남부     광주공장          30       남부
# 3   수원창고        42       북부     수원공장          29       북부
# 4   용인창고        41       북부     서울공장          28       북부
